# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %% [markdown]
# Observe Dataset

# %%
df = pd.read_csv('/content/sentiment_tweets3.csv')

# %%
df.head()
# Out:
#    Index                                 message to examine  \
# 0    106  just had a real good moment. i missssssssss hi...
# 1    217         is reading manga  http://plurk.com/p/mzp1e
# 2    220  @comeagainjen http://twitpic.com/2y2lx - http:...
# 3    288  @lapcat Need to send 'em to my accountant tomo...
# 4    540      ADD ME ON MYSPACE!!!  myspace.com/LookThunder
#
#    label (depression result)
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0

# %%
df['label (depression result)'].value_counts()
# Out:
# label (depression result)
# 0    8000
# 1    2314
# Name: count, dtype: int64

# %%
selected_rows = df[df['label (depression result)'] == 0].head(2314)

# %%
selected_rows1= df[df['label (depression result)'] == 1].head(2314)

# %%
combined_df = pd.concat([selected_rows1,selected_rows], ignore_index=True)

# %%
combined_df['label (depression result)'].value_counts()
# Out:
# label (depression result)
# 1    2314
# 0    2314
# Name: count, dtype: int64

# %%
combined_df.tail()
# Out:
#        Index                                 message to examine  \
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0

# %%
combined_df.loc[1031]['message to examine']
# Out:
# "@cuzyourehotshot @lovelyzband @infinitens97 it's not depression it's anxiety and i will let her know <Emoji: Face with tears of joy>"

# %%
combined_df.loc[3]['message to examine']
# Out:
# 'Made myself a tortilla filled with pb&j. My depression is cured. Olivia:1 depression:0'

# %%
combined_df.loc[1234]['message to examine']
# Out:
# "@Psychobiotic @ajit9988 It's intriguing...but...I hear people talking about probiotics for depression and I wonder...is this vitamin supplements and herbal remedies for millennials approaching middle age?"

# %%
combined_df.isnull().sum()
# Out:
# Index                        0
# message to examine           0
# label (depression result)    0
# dtype: int64

# %%
# Check if there's any number

for i in combined_df['message to examine']:
  for j in i.split():
    if j.isdigit():
      s = "yes"
    else:
      s = "no"
print(s)
# Out:
# no

# %% [markdown]
# **Remove Numbers**

# %%
import re

# %%
# First Remove all the numbers

def remove_numbers(text):
  return ' '.join([i for i in str(text).split() if not i.isdigit()])

combined_df['clean_tweets'] = combined_df['message to examine'].apply(lambda x: remove_numbers(x))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# ...      ...                                                ...
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0
#
#                                            clean_tweets
# 0     The lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     Made myself a tortilla filled with pb&j. My de...
# 4     @WorldofOutlaws I am gonna need depression med...
# ...                                                 ...
# 4623   my BIS connection is KapuT, no BBM, feels lonely
# 4624  I love how non-chalant &amp; blunt Tony Montan...
# 4625  Glad to have gotten outta bed on my way back h...
# 4626  @FRin323 none of that!! I can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
# [4628 rows x 4 columns]

# %%
# Lowercasing all the tweets

combined_df['clean_tweets'] = combined_df['clean_tweets'].str.lower()

# %% [markdown]
# **Remove Weblinks**

# %%
# Removal of Weblinks

def remove_weblinks(text):
  return re.sub(r"http\S+", "", text)

combined_df['clean_tweets2'] = combined_df['clean_tweets'].apply(lambda x: remove_weblinks(x))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# ...      ...                                                ...
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0
#
#                                            clean_tweets  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets2
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
# [4628 rows x 5 columns]

# %% [markdown]
# **Remove Twitter Mentions**

# %%
def remove_twitter(text):
  return re.sub('@[\w]+','',text)

# %%
combined_df['clean_tweets3'] = combined_df['clean_tweets2'].apply(lambda x: remove_twitter(x))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# ...      ...                                                ...
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0
#
#                                            clean_tweets  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets2  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets3
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4      i am gonna need depression meds soon, these r...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626   none of that!! i can't wait!!! so when the bi...
# 4627                            &lt;333333333 love you!
#
# [4628 rows x 6 columns]

# %% [markdown]
# **Removal of Punctuations**

# %%
import string

# %%
PUNCT_TO_REMOVE = string.punctuation

# %%
def remove_punctuation(text):
  return text.translate(str.maketrans('','', PUNCT_TO_REMOVE))

# %%
combined_df['clean_tweets4'] = combined_df['clean_tweets3'].apply(lambda x: remove_punctuation(x))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %%
STOPWORDS = set(stopwords.words('english'))

def remove_stopwords(text):
  return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# %%
combined_df['clean_tweets5'] = combined_df['clean_tweets4'].apply(lambda x: remove_stopwords(x))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# ...      ...                                                ...
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0
#
#                                            clean_tweets  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets2  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets3  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4      i am gonna need depression meds soon, these r...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626   none of that!! i can't wait!!! so when the bi...
# 4627                            &lt;333333333 love you!
#
#                                           clean_tweets4  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i dont speak about eve...
# 3     made myself a tortilla filled with pbj my depr...
# 4      i am gonna need depression meds soon these ra...
# ...                                                 ...
# 4623     my bis connection is kaput no bbm feels lonely
# 4624  i love how nonchalant amp blunt tony montana w...
# 4625  glad to have gotten outta bed on my way back h...
# 4626       none of that i cant wait so when the big day
# 4627                               lt333333333 love you
#
#                                           clean_tweets5
# 0     lack understanding small significant part caus...
# 1     told parents depression hard get gen x people ...
# 2     depression something dont speak even going als...
# 3     made tortilla filled pbj depression cured oliv...
# 4     gonna need depression meds soon rainouts spinn...
# ...                                                 ...
# 4623              bis connection kaput bbm feels lonely
# 4624  love nonchalant amp blunt tony montana didnt g...
# 4625  glad gotten outta bed way back home refreshing...
# 4626                             none cant wait big day
# 4627                                   lt333333333 love
#
# [4628 rows x 8 columns]

# %% [markdown]
# **Frequent Words**

# %%
from collections import Counter
cnt = Counter()

for text in combined_df['clean_tweets5'].values:
  for word in text.split():
    cnt[word] += 1

cnt.most_common(10)
# Out:
# [('depression', 2285),
#  ('im', 485),
#  ('â\x80¦', 374),
#  ('anxiety', 360),
#  ('like', 302),
#  ('good', 273),
#  ('dont', 241),
#  ('day', 230),
#  ('know', 215),
#  ('get', 212)]

# %% [markdown]
# **Rare words**

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])

# Let's see what are the Rarewords

RAREWORDS
# Out:
# {'approval',
#  'bbm',
#  'bis',
#  'casts',
#  'designquot',
#  'kaput',
#  'lt333333333',
#  'metsaw',
#  'nonchalant',
#  'quotmurder'}

# %%
# Let's remove these

def remove_stopwords(text):
  return " ".join([word for word in str(text).split() if word not in RAREWORDS])

# %%
combined_df['clean_tweets6'] = combined_df['clean_tweets5'].apply(lambda x: remove_stopwords(x))

# %% [markdown]
# **Lemmatization**

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

wordnet_map = {"n": wordnet.NOUN, "v": wordnet.VERB, "j": wordnet.ADJ, "r": wordnet.ADV}

def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.VERB)) for word, pos in pos_tagged_text])

combined_df["text_lemmatized"] = combined_df['clean_tweets6'].apply(lambda text: lemmatize_words(text))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# 1     told parents depression hard get gen x people ...
# 2     depression something dont speak even going als...
# 3     made tortilla filled pbj depression cured oliv...
# 4     gonna need depression meds soon rainouts spinn...
# ...                                                 ...
# 4623                            connection feels lonely
# 4624  love amp blunt tony montana didnt give f nobod...
# 4625  glad gotten outta bed way back home refreshing...
# 4626                             none cant wait big day
# 4627                                               love
#
#                                         text_lemmatized
# 0     lack understand small significant part cause a...
# 1     tell parent depression hard get gen x people u...
# 2     depression something dont speak even go also d...
# 3     make tortilla fill pbj depression cure olivia1...
# 4     gonna need depression meds soon rainouts spin ...
# ...                                                 ...
# 4623                             connection feel lonely
# 4624  love amp blunt tony montana didnt give f nobod...
# 4625   glad get outta bed way back home refresh workout
# 4626                             none cant wait big day
# 4627                                               love
#
# [4628 rows x 10 columns]

# %% [markdown]
# **Replace some short words**

# %%
short_words = {
"aint": "am not",
"arent": "are not",
"cant": "cannot",
"'cause": "because",
"couldve": "could have",
"couldnt": "could not",
"didnt": "did not",
"doesnt": "does not",
"dont": "do not",
"hadnt": "had not",
"hasnt": "has not",
"havent": "have not",
"im": "I am",
"em": "them",
"ive": "I have",
"isnt": "is not",
"lets": "let us",
"theyre": "they are",
"theyve": "they have",
"wasnt": "was not",
"well": "we will",
"were": "we are",
"werent": "were not",
"you're": "you are",
"you've": "you have"
}

# %%
def replace_short_words(text):
  for word in text.split():
    if word in short_words:
      text = text.replace(word, short_words[word])

  return text

# %%
combined_df["clean_tweets7"] = combined_df['text_lemmatized'].apply(lambda text: replace_short_words(text))

# %%
combined_df
# Out:
#        Index                                 message to examine  \
# 0     800000  The lack of this understanding is a small but ...
# 1     800001  i just told my parents about my depression and...
# 2     800002  depression is something i don't speak about ev...
# 3     800003  Made myself a tortilla filled with pb&j. My de...
# 4     800004  @WorldofOutlaws I am gonna need depression med...
# ...      ...                                                ...
# 4623  235935  my BIS connection is KapuT, no BBM, feels lonely
# 4624  236037  I love how non-chalant &amp; blunt Tony Montan...
# 4625  236412  Glad to have gotten outta bed  on my way back ...
# 4626  236419  @FRin323 none of that!! I can't wait!!!  so wh...
# 4627  236420                  @brendax &lt;333333333 love you!
#
#       label (depression result)  \
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 4623                          0
# 4624                          0
# 4625                          0
# 4626                          0
# 4627                          0
#
#                                            clean_tweets  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 2     depression is something i don't speak about ev...
# 3     made myself a tortilla filled with pb&j. my de...
# 4     @worldofoutlaws i am gonna need depression med...
# ...                                                 ...
# 4623   my bis connection is kaput, no bbm, feels lonely
# 4624  i love how non-chalant &amp; blunt tony montan...
# 4625  glad to have gotten outta bed on my way back h...
# 4626  @frin323 none of that!! i can't wait!!! so whe...
# 4627                   @brendax &lt;333333333 love you!
#
#                                           clean_tweets2  \
# 0     the lack of this understanding is a small but ...
# 1     i just told my parents about my depression and...
# 4626                           none cannot wait big day
# 4627                                               love
#
# [4628 rows x 11 columns]

# %% [markdown]
# **Our text is clean and ready for training. But let's delete all the previous columns.**

# %%
xdf = combined_df[['Index','label (depression result)','clean_tweets7']]

# %%
xdf
# Out:
#        Index  label (depression result)  \
# 0     800000                          1
# 1     800001                          1
# 2     800002                          1
# 3     800003                          1
# 4     800004                          1
# ...      ...                        ...
# 4623  235935                          0
# 4624  236037                          0
# 4625  236412                          0
# 4626  236419                          0
# 4627  236420                          0
#
#                                           clean_tweets7
# 0     lack understand small significant part cause a...
# 1     tell parent depression hard get gen x people u...
# 2     depression something do not speak even go also...
# 3     make tortilla fill pbj depression cure olivia1...
# 4     gonna need depression meds soon rainouts spin ...
# ...                                                 ...
# 4623                             connection feel lonely
# 4624  love amp blunt tony montana did not give f nob...
# 4625   glad get outta bed way back home refresh workout
# 4626                           none cannot wait big day
# 4627                                               love
#
# [4628 rows x 3 columns]

# %%
xdf.columns = ['Index','Labels','Tweets']

# %%
xdf
# Out:
#        Index  Labels                                             Tweets
# 0     800000       1  lack understand small significant part cause a...
# 1     800001       1  tell parent depression hard get gen x people u...
# 2     800002       1  depression something do not speak even go also...
# 3     800003       1  make tortilla fill pbj depression cure olivia1...
# 4     800004       1  gonna need depression meds soon rainouts spin ...
# ...      ...     ...                                                ...
# 4623  235935       0                             connection feel lonely
# 4624  236037       0  love amp blunt tony montana did not give f nob...
# 4625  236412       0   glad get outta bed way back home refresh workout
# 4626  236419       0                           none cannot wait big day
# 4627  236420       0                                               love
#
# [4628 rows x 3 columns]

# %%
# Plot the word cloud

from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
sentences = xdf['Tweets'].tolist()

# %%
len(sentences)
# Out:
# 4628

# %%
# Joining sentences (combining all the sentences that we have)

joined_sentences = " ".join(sentences)

# %%
plt.figure(figsize = (12,8))
plt.imshow(WordCloud().generate(joined_sentences));

# %%
xdf['Labels'].value_counts()
# Out:
# Labels
# 1    2314
# 0    2314
# Name: count, dtype: int64

# %% [markdown]
# # Let's visualize postive and negative tweets

# %%
positive_tweets = xdf[xdf['Labels'] == 0]
positive_sentences = positive_tweets['Tweets'].tolist()
positive_string = " ".join(positive_sentences)

# %%
plt.figure(figsize = (12,8))
plt.imshow(WordCloud().generate(positive_string));

# %% [markdown]
# # Let's visualize negative tweets
#
# **bold text**

# %%
negative_tweets = xdf[xdf['Labels'] == 1]
negative_sentences = negative_tweets['Tweets'].tolist()
negative_string = " ".join(negative_sentences)

# %%
plt.figure(figsize = (12,8))
plt.imshow(WordCloud().generate(negative_string));

# %% [markdown]
# **Basic Sentiment Analaysis**
# First, we will build our model with Basic Sentiment Analysis technique with tf-idf and NaiveBayes Classifier

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv = TfidfVectorizer()

# %%
tfidf = cv.fit_transform(xdf['Tweets'])

# %% [markdown]
# **Splitting Dataset**

# %%
from sklearn.model_selection import train_test_split

# %%
tfX_train, tfX_test, tfy_train, tfy_test = train_test_split(tfidf, xdf['Labels'], test_size = 0.2)

# %%
tfX_train
# Out:
# <3702x9615 sparse matrix of type '<class 'numpy.float64'>'
# 	with 35047 stored elements in Compressed Sparse Row format>

# %%
tfX_train.shape
# Out:
# (3702, 9615)

# %% [markdown]
# **Models and Evaluation**

# %%
## NaiveBayes

from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()

# %%
mnb.fit(tfX_train, tfy_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

y_pred_mnb = mnb.predict(tfX_test)

print(f'Accuracy score is : {accuracy_score(tfy_test, y_pred_mnb)}')
# Out:
# Accuracy score is : 0.8995680345572354

# %%
cf = confusion_matrix(tfy_test, y_pred_mnb, labels = [1,0])
cf
# Out:
# array([[428,  28],
#        [ 65, 405]])

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

plt.figure(figsize = (8,6))
sns.set(font_scale=1)
sns.heatmap(cf, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# **Better Sentiment Analaysis**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Embedding,LSTM, SimpleRNN ,Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
import tensorflow_hub as hub

# %%
# Load Pretrained Word2Vec

embed = hub.load("https://tfhub.dev/google/Wiki-words-250/2")

# %%
def get_max_length(df):
  ## get max token counts from train data,
  ## so we use this number as fixed length input to RNN cell

  max_length = 0
  for row in xdf['Tweets']:
    if len(row.split(" ")) > max_length:
      max_length = len(row.split(" "))

  return max_length

# %%
get_max_length(xdf['Tweets'])
# Out:
# 51

# %%
def get_word2vec_enc(tweets):
  ## get word2vec value for each word in sentence
  # concatenate word in numpy array, so we can use it as RNN input

  encoded_tweets = []
  for tweet in tweets:
    tokens = tweet.split(" ")
    word2vec_embedding = embed(tokens)
    encoded_tweets.append(word2vec_embedding)
  return encoded_tweets

# %%
def get_padded_encoded_tweets(encoded_tweets):
  # for short sentences, we prepend zero padding so all input to RNN
  # has same length

  padded_tweets_encoding = []
  for enc_tweet in encoded_tweets:
    zero_padding_cnt = max_length - enc_tweet.shape[0]
    pad = np.zeros((1, 250))
    for i in range(zero_padding_cnt):
      enc_tweet = np.concatenate((pad, enc_tweet), axis = 0)
    padded_tweets_encoding.append(enc_tweet)
  return padded_tweets_encoding

# %%
def sentiment_encode(sentiment):
    if sentiment == 0:
        return [0,1]
    else:
        return [1,0]

# %%
def preprocess(df):
  # encode text value to numeric value

  tweets = df['Tweets'].tolist()

  encoded_tweets = get_word2vec_enc(tweets)
  padded_encoded_tweets = get_padded_encoded_tweets(encoded_tweets)

  #encoded sentiment
  sentiments = df['Labels'].tolist()
  encoded_sentiment = [sentiment_encode(sentiment) for sentiment in sentiments]

  X = np.array(padded_encoded_tweets)
  Y = np.array(encoded_sentiment)

  return X, Y

# %%
# Preprocess

max_length = get_max_length(xdf)
max_length
# Out:
# 51

# %%
tdf = xdf.sample(frac = 1)
train = tdf[:3702]
test = tdf[3702:]

# %%
train.shape, test.shape
# Out:
# ((3702, 3), (926, 3))

# %%
train_X, train_Y = preprocess(train)
test_X, test_Y = preprocess(test)

# %%
## Build Model

# %%
# LSTM

model = Sequential()
model.add(Bidirectional(LSTM(32)))
model.add(Dense(2, activation = 'softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# **Train**

# %%
model.fit(train_X, train_Y, epochs = 10)
# Out:
# Epoch 1/10
# 116/116 [==============================] - 13s 63ms/step - loss: 0.2798 - accuracy: 0.8817
# Epoch 2/10
# 116/116 [==============================] - 6s 50ms/step - loss: 0.0856 - accuracy: 0.9757
# Epoch 3/10
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0718 - accuracy: 0.9789
# Epoch 4/10
# 116/116 [==============================] - 6s 52ms/step - loss: 0.0639 - accuracy: 0.9816
# Epoch 5/10
# 116/116 [==============================] - 9s 75ms/step - loss: 0.0604 - accuracy: 0.9827
# Epoch 6/10
# 116/116 [==============================] - 6s 53ms/step - loss: 0.0577 - accuracy: 0.9835
# Epoch 7/10
# 116/116 [==============================] - 7s 62ms/step - loss: 0.0576 - accuracy: 0.9824
# Epoch 8/10
# 116/116 [==============================] - 6s 54ms/step - loss: 0.0586 - accuracy: 0.9819
# Epoch 9/10
# 116/116 [==============================] - 7s 61ms/step - loss: 0.0504 - accuracy: 0.9857
# Epoch 10/10
# 116/116 [==============================] - 6s 53ms/step - loss: 0.0489 - accuracy: 0.9854

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirecti  (None, 64)                72448
#  onal)
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 72578 (283.51 KB)
# Trainable params: 72578 (283.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Test**

# %%
score, acc = model.evaluate(test_X, test_Y, verbose = 2)
print("Test Score:", score)
print("Test Accuracy:", acc)
# Out:
# 29/29 - 1s - loss: 0.0488 - accuracy: 0.9870 - 1s/epoch - 50ms/step
# Test Score: 0.04878513514995575
# Test Accuracy: 0.9870410561561584

# %%
# Confusion Matrix

y_pred = model.predict(test_X)
# Out:
# 29/29 [==============================] - 1s 19ms/step

# %%
import sklearn.metrics as metrics

# %%
matrix = metrics.confusion_matrix(test_Y.argmax(axis = 1), y_pred.argmax(axis = 1), labels = [1,0])

# %%
matrix
# Out:
# array([[451,   3],
#        [  9, 463]])

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

plt.figure(figsize = (8,6))
sns.set(font_scale=1)
sns.heatmap(matrix, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %%
# Save Model
with open('model1.pkl','wb') as f:
    pickle.dump(model,f)

# Load model
with open('model1.pkl', 'rb') as f:
    model = pickle.load(f)
